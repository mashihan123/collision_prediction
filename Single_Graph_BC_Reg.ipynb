# %%
import torch
import random
import numpy as np
from itertools import chain
import torch.nn as nn
import itertools as it
import os, shutil
import pandas as pd
from pandas.core.common import flatten
from scipy.interpolate import make_interp_spline, interp1d
import matplotlib.pyplot as plt
from IPython.display import clear_output
import math
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
from tqdm import tqdm
# %cd GraphSSL
# Out:
# /home/shihan/GAT/GraphSSL

# %% [markdown]
# ### Customized Dataset

# %%
random.seed(42)
t_threshold = 1.5  # in seconds
min_d_threshold = 30  # in meters
t_prediction = 15 # in frames
sequence_dist = 40 # in frames

# %%
info_dir = '../csv_final/info/'   # directory of 'info' folder
all_info = []
for filename in os.listdir(info_dir):
    if filename.endswith('txt'):
        all_info.append(filename)
pedestrian = []
rear_end = []
switch_lane = [] # switch_lane
t_bone = []
opposite_front = []
opposite_merge = []
merging = []
other = []
for info in all_info:
    txt_file = open(info_dir+info, "r").read().split('\n') # split txt file with lines
    first_cls = txt_file[2].split(': ')[-1]
    second_cls = txt_file[9].split(': ')[-1]
    first_fault = txt_file[7].split(' ')[-1]
    second_fault = txt_file[14].split(' ')[-1]
    first_direction = txt_file[5].split(' ')[-1]
    second_direction = txt_file[12].split(' ')[-1]
    first_collision_side = txt_file[6].split(' ')[-1]
    second_collision_side = txt_file[13].split(' ')[-1]
    second_relative_direction_to_first = txt_file[15].split(' ')[-1]
    if first_cls == 'pedestrian' or second_cls == 'pedestrian':
        pedestrian.append(info)
    elif first_fault == 'rear_end' or second_fault == 'rear_end':
        rear_end.append(info)
    elif first_fault == 'switch_lane' or second_fault == 'switch_lane':
        switch_lane.append(info)
    elif first_direction == 'straight' and second_direction == 'straight':
        t_bone.append(info)
    elif second_relative_direction_to_first == 'opposite' and 'straight' in [first_direction, second_direction]:
        opposite_front.append(info)
    elif second_relative_direction_to_first == 'opposite':
        opposite_merge.append(info)
    elif first_fault == 'entrance_ramp' or second_fault == 'entrance_ramp':
        merging.append(info)
    elif second_relative_direction_to_first=='right' and first_direction=='left' and second_direction=='straight':
        merging.append(info)
    elif second_relative_direction_to_first=='left' and first_direction=='straight' and second_direction=='left':
        merging.append(info)
    elif second_relative_direction_to_first=='right' and first_direction=='straight' and second_direction=='right':
        merging.append(info)
    elif second_relative_direction_to_first=='left' and first_direction=='right' and second_direction=='straight':
        merging.append(info)
    else:
        other.append(info)
random.shuffle(pedestrian)
random.shuffle(rear_end)
random.shuffle(switch_lane)
random.shuffle(t_bone)
random.shuffle(opposite_front)
random.shuffle(opposite_merge)
random.shuffle(merging)
random.shuffle(other)
acc_all = {'pedestrian':len(pedestrian), 'rear_end':len(rear_end),
        'switch_lane':len(switch_lane), 't_bone':len(t_bone),
        'opposite_front':len(opposite_front), 'opposite_merge': len(opposite_merge),
        'merging':len(merging), 'other':len(other),
        'total': len(pedestrian+rear_end+switch_lane+t_bone+opposite_front+opposite_merge+merging+other)}
print(acc_all)
acc_train = {'pedestrian':math.ceil(len(pedestrian)*0.8), 'rear_end':math.ceil(len(rear_end)*0.8),
        'switch_lane':math.ceil(len(switch_lane)*0.8), 't_bone':math.ceil(len(t_bone)*0.8),
        'opposite_front':math.ceil(len(opposite_front)*0.8), 'opposite_merge': math.ceil(len(opposite_merge)*0.8),
        'merging':math.ceil(len(merging)*0.8), 'other':math.ceil(len(other)*0.8)}
acc_test = {'pedestrian':int(len(pedestrian)/5), 'rear_end':int(len(rear_end)/5),
        'switch_lane':int(len(switch_lane)/5), 't_bone':int(len(t_bone)/5),
        'opposite_front':int(len(opposite_front)/5), 'opposite_merge': int(len(opposite_merge)/5),
        'merging':int(len(merging)/5), 'other':int(len(other)/5)
        }
print('training dataset:')
print(acc_train)
print('testing dataset:')
print(acc_test)
# Out:
# {'pedestrian': 8, 'rear_end': 19, 'switch_lane': 13, 't_bone': 31, 'opposite_front': 22, 'opposite_merge': 19, 'merging': 40, 'other': 44, 'total': 196}
# training dataset:
# {'pedestrian': 7, 'rear_end': 16, 'switch_lane': 11, 't_bone': 25, 'opposite_front': 18, 'opposite_merge': 16, 'merging': 32, 'other': 36}
# testing dataset:
# {'pedestrian': 1, 'rear_end': 3, 'switch_lane': 2, 't_bone': 6, 'opposite_front': 4, 'opposite_merge': 3, 'merging': 8, 'other': 8}

# %%
accident_dir = '../csv_final/accident/'
normal_dir = '../csv_final/normal/'
train_scene_list = []
test_scene_list = []
accident_names = ['pedestrian','rear_end','switch_lane','t_bone','opposite_front','opposite_merge','merging','other']
all_names = accident_names+['no_accident']
major_acc_num = 36
accident_type_all = [pedestrian,rear_end,switch_lane,t_bone,opposite_front,opposite_merge,merging,other]
balanced_all_acc_train = []
for accident_type in accident_type_all:
    random.shuffle(accident_type)
    test_scene_list += accident_type[ : int(len(accident_type)/5)]
    # train_scene_list += accident_type[int(len(accident_type)/5) : ]
    train_num_accident_type = math.ceil(len(accident_type)*0.8)
    minor_class_multiplier = int(major_acc_num/train_num_accident_type)
    balanced_all_acc_train.append(accident_type[int(len(accident_type)/5):]*minor_class_multiplier 
                                  + accident_type[int(len(accident_type)/5):][:major_acc_num-math.ceil(len(accident_type)*0.8)*minor_class_multiplier])
    train_scene_list = train_scene_list + accident_type[int(len(accident_type)/5):]*minor_class_multiplier + accident_type[int(len(accident_type)/5):][:major_acc_num-math.ceil(len(accident_type)*0.8)*minor_class_multiplier]
normal_scene_list = []
for filename in os.listdir(normal_dir):
    if filename.endswith('csv'):
        normal_scene_list.append(filename)
random.shuffle(normal_scene_list)
# train_scene_list += normal_scene_list[len(test_scene_list) : len(test_scene_list)+len(train_scene_list)]
# test_scene_list += normal_scene_list[ : len(test_scene_list)]

# %%
# dataset_train = []
# test_scene_list += normal_scene_list[ : len(test_scene_list)]
for scene in train_scene_list:
    if scene in normal_scene_list:
        # y = 0
        df = pd.read_csv(normal_dir+scene.replace('.txt','.csv'))  # read the i-th csv file
        crash_frame_id = df[-1:]['frame_id'].item()
        crash_ids = [314159, 314159]
    else:
        # y = 1
        df = pd.read_csv(accident_dir+scene.replace('.txt','.csv'))
        crash_frame_id = min(df[df['acc_inv'] == 1]['frame_id'].tolist())
        crash_ids = df[df['acc_inv'] == 1]['obj_id'].tolist() 
    crash_pred_frame_id = crash_frame_id - 1
    if t_prediction+sequence_dist+t_prediction <= crash_pred_frame_id:
        pred_frame_id_list = [crash_pred_frame_id-t_prediction-sequence_dist, crash_pred_frame_id]
    else:
        pred_frame_id_list = [t_prediction-1, crash_pred_frame_id]
    print(scene)
    for pred_frame_id in pred_frame_id_list:
        for frame_id in range(pred_frame_id-t_prediction+1, pred_frame_id+1):
            df_frame = df[df['frame_id'] == frame_id]
            df_numeric = df_frame[['x_center', 'y_center', 'bbox_x', 'bbox_y', 'vel_x', 'vel_y']]
            # x_numeric = torch.tensor(df_numeric.to_numpy(), dtype=torch.float)
            df_numeric_norm = df_numeric / df_numeric.to_numpy().max() 
            id_list = df_frame['obj_id'].tolist()  # all node ids in predicted frame
            node_idx_list = list(range(len(id_list)))
            df_dummies = pd.get_dummies(df_frame[['obj_cls']].astype(pd.CategoricalDtype(categories=['car',
                                                                                        'van',
                                                                                        'truck',
                                                                                        'motorcycle',
                                                                                        'cyclist',
                                                                                        'pedestrian'
                                                                                        ])), dtype=float)
            df_features = pd.concat([df_dummies, df_numeric_norm], axis=1)
            node_features = df_features.to_numpy()
            edge_index = [[],[]]
            edge_features = []
            edge_id = []
            for node_connection in it.combinations(node_idx_list, 2):
                x1 = df_numeric['x_center'].tolist()[node_connection[0]]
                y1 = df_numeric['y_center'].tolist()[node_connection[0]]
                v_x1 = df_numeric['vel_x'].tolist()[node_connection[0]]
                v_y1 = df_numeric['vel_y'].tolist()[node_connection[0]]
                x2 = df_numeric['x_center'].tolist()[node_connection[1]]
                y2 = df_numeric['y_center'].tolist()[node_connection[1]]
                v_x2 = df_numeric['vel_x'].tolist()[node_connection[1]]
                v_y2 = df_numeric['vel_y'].tolist()[node_connection[1]]
                delta_x = x2 - x1
                delta_y = y2 - y1
                delta_v_x = v_x1 - v_x2
                delta_v_y = v_y1 - v_y2
                if delta_v_x**2+delta_v_y**2 == 0:
                    min_d = math.sqrt(delta_x**2+delta_y**2)
                    t_accident = 0
                else:
                    t_accident = (delta_x*delta_v_x+delta_y*delta_v_y)/(delta_v_x**2+delta_v_y**2)
                    if t_accident < 0:
                        min_d = math.sqrt(delta_x**2+delta_y**2)
                    else:
                        min_d = abs((delta_x*delta_v_y-delta_y*delta_v_x))/math.sqrt(delta_v_x**2+delta_v_y**2)
                if min_d <= min_d_threshold:
                    edge_index[0].append(node_connection[0])
                    edge_index[0].append(node_connection[1])
                    edge_index[1].append(node_connection[1])
                    edge_index[1].append(node_connection[0])
                    edge_features.append([t_accident, min_d])
                    edge_features.append([t_accident, min_d])
                    edge_id.append([id_list[node_connection[0]], id_list[node_connection[1]]])
                    edge_id.append([id_list[node_connection[1]], id_list[node_connection[0]]])
            edge_features_norm = nn.functional.normalize(torch.tensor(edge_features, dtype=torch.float), p=1.0, dim = 0)
            if pred_frame_id_list.index(pred_frame_id) == 0:
                y = torch.tensor([0], dtype=torch.long)
            else:
                y = torch.tensor([1], dtype=torch.long)
            data = Data(edge_index = torch.tensor(edge_index, dtype=torch.long),
                        x = torch.tensor(node_features, dtype=torch.float),
                        edge_attr = edge_features_norm,
                        y = y,
                        frame_to_crash = torch.tensor(crash_frame_id-frame_id, dtype=torch.float),
                        # crash_node_idx = torch.tensor([crash_node_idx], dtype=torch.long)
                        obj_ids = torch.tensor(id_list, dtype=torch.long),
                        crash_ids = torch.tensor(crash_ids, dtype=torch.long)
                        )
            dataset_train.append(data)
# Out:
# train_09_Town05_type001_subtype0002_scenario00006.txt
# train_09_Town03_type001_subtype0002_scenario00027.txt
# Mini_ds_Town05_type001_subtype0001_scenario00007.txt
# train_01_Town10HD_type001_subtype0002_scenario00005.txt
# train_08_Town02_type001_subtype0001_scenario00009.txt
# train_04_Town04_type001_subtype0001_scenario00033.txt
# train_04_Town05_type001_subtype0001_scenario00007.txt
# train_09_Town05_type001_subtype0002_scenario00006.txt
# train_09_Town03_type001_subtype0002_scenario00027.txt
# Mini_ds_Town05_type001_subtype0001_scenario00007.txt
# train_01_Town10HD_type001_subtype0002_scenario00005.txt
# train_08_Town02_type001_subtype0001_scenario00009.txt
# train_04_Town04_type001_subtype0001_scenario00033.txt
# train_04_Town05_type001_subtype0001_scenario00007.txt
# train_09_Town05_type001_subtype0002_scenario00006.txt
# train_09_Town03_type001_subtype0002_scenario00027.txt
# Mini_ds_Town05_type001_subtype0001_scenario00007.txt
# train_01_Town10HD_type001_subtype0002_scenario00005.txt
# train_08_Town02_type001_subtype0001_scenario00009.txt
# train_04_Town04_type001_subtype0001_scenario00033.txt
# train_04_Town05_type001_subtype0001_scenario00007.txt
# train_09_Town05_type001_subtype0002_scenario00006.txt
# train_09_Town03_type001_subtype0002_scenario00027.txt
# Mini_ds_Town05_type001_subtype0001_scenario00007.txt
# train_01_Town10HD_type001_subtype0002_scenario00005.txt
# train_08_Town02_type001_subtype0001_scenario00009.txt
# train_04_Town04_type001_subtype0001_scenario00033.txt
# train_04_Town05_type001_subtype0001_scenario00007.txt
# train_09_Town05_type001_subtype0002_scenario00006.txt
# train_09_Town03_type001_subtype0002_scenario00027.txt
# Mini_ds_Town05_type001_subtype0001_scenario00007.txt
# train_01_Town10HD_type001_subtype0002_scenario00005.txt
# train_08_Town02_type001_subtype0001_scenario00009.txt
# train_04_Town04_type001_subtype0001_scenario00033.txt
# train_04_Town05_type001_subtype0001_scenario00007.txt
# train_09_Town05_type001_subtype0002_scenario00006.txt
# train_06_Town03_type001_subtype0002_scenario00021.txt
# train_08_Town04_type001_subtype0002_scenario00007.txt
# train_09_Town07_type001_subtype0002_scenario00022.txt
# train_02_Town10HD_type001_subtype0001_scenario00031.txt
# train_04_Town10HD_type001_subtype0001_scenario00029.txt
# Mini_ds_Town02_type001_subtype0001_scenario00013.txt
# train_02_Town03_type001_subtype0002_scenario00026.txt
# train_03_Town10HD_type001_subtype0002_scenario00014.txt
# train_04_Town03_type001_subtype0001_scenario00036.txt
# train_07_Town10HD_type001_subtype0002_scenario00002.txt
# train_02_Town02_type001_subtype0001_scenario00013.txt
# train_08_Town01_type001_subtype0001_scenario00012.txt
# train_07_Town07_type001_subtype0002_scenario00002.txt
# train_09_Town02_type001_subtype0001_scenario00003.txt
# train_01_Town07_type001_subtype0002_scenario00036.txt
# train_03_Town07_type001_subtype0002_scenario00009.txt
# train_06_Town03_type001_subtype0002_scenario00021.txt
# train_08_Town04_type001_subtype0002_scenario00007.txt
# train_09_Town07_type001_subtype0002_scenario00022.txt
# train_02_Town10HD_type001_subtype0001_scenario00031.txt
# train_04_Town10HD_type001_subtype0001_scenario00029.txt
# Mini_ds_Town02_type001_subtype0001_scenario00013.txt
# train_02_Town03_type001_subtype0002_scenario00026.txt
# train_03_Town10HD_type001_subtype0002_scenario00014.txt
# train_04_Town03_type001_subtype0001_scenario00036.txt
# train_07_Town10HD_type001_subtype0002_scenario00002.txt
# train_02_Town02_type001_subtype0001_scenario00013.txt
# train_08_Town01_type001_subtype0001_scenario00012.txt
# train_07_Town07_type001_subtype0002_scenario00002.txt
# train_09_Town02_type001_subtype0001_scenario00003.txt
# train_01_Town07_type001_subtype0002_scenario00036.txt
# train_03_Town07_type001_subtype0002_scenario00009.txt
# train_06_Town03_type001_subtype0002_scenario00021.txt
# train_08_Town04_type001_subtype0002_scenario00007.txt
# train_09_Town07_type001_subtype0002_scenario00022.txt
# train_02_Town10HD_type001_subtype0001_scenario00031.txt
# train_07_Town03_type001_subtype0002_scenario00035.txt
# train_09_Town03_type001_subtype0002_scenario00019.txt
# train_08_Town05_type001_subtype0001_scenario00027.txt
# train_07_Town05_type001_subtype0001_scenario00021.txt
# train_03_Town03_type001_subtype0001_scenario00029.txt
# train_04_Town05_type001_subtype0001_scenario00011.txt
# train_02_Town03_type001_subtype0002_scenario00016.txt
# train_09_Town05_type001_subtype0002_scenario00024.txt
# train_07_Town03_type001_subtype0002_scenario00015.txt
# train_05_Town03_type001_subtype0002_scenario00012.txt
# val_01_Town03_type001_subtype0002_scenario00028.txt
# train_07_Town03_type001_subtype0002_scenario00035.txt
# train_09_Town03_type001_subtype0002_scenario00019.txt
# train_08_Town05_type001_subtype0001_scenario00027.txt
# train
# train_07_Town02_type001_subtype0001_scenario00014.txt
# train_08_Town03_type001_subtype0002_scenario00006.txt
# train_04_Town04_type001_subtype0002_scenario00008.txt
# train_08_Town04_type001_subtype0002_scenario00003.txt
# val_02_Town03_type001_subtype0002_scenario00017.txt
# train_06_Town05_type001_subtype0002_scenario00023.txt
# train_05_Town05_type001_subtype0002_scenario00009.txt
# train_06_Town10HD_type001_subtype0001_scenario00007.txt
# train_07_Town04_type001_subtype0002_scenario00016.txt
# val_01_Town03_type001_subtype0001_scenario00006.txt
# train_03_Town04_type001_subtype0002_scenario00015.txt
# train_03_Town04_type001_subtype0002_scenario00017.txt
# train_09_Town04_type001_subtype0002_scenario00019.txt
# train_01_Town03_type001_subtype0001_scenario00007.txt
# train_02_Town05_type001_subtype0001_scenario00012.txt
# train_04_Town02_type001_subtype0001_scenario00008.txt
# train_07_Town07_type001_subtype0001_scenario00015.txt
# train_03_Town04_type001_subtype0002_scenario00012.txt

# %%
group_train = []
# test_scene_list += normal_scene_list[ : len(test_scene_list)]
for accident_class in balanced_all_acc_train:
    sub_class = []
    for scene in accident_class:
        if scene in normal_scene_list:
            # y = 0
            df = pd.read_csv(normal_dir+scene.replace('.txt','.csv'))  # read the i-th csv file
            crash_frame_id = df[-1:]['frame_id'].item()
            crash_ids = [314159, 314159]
        else:
            # y = 1
            df = pd.read_csv(accident_dir+scene.replace('.txt','.csv'))
            crash_frame_id = min(df[df['acc_inv'] == 1]['frame_id'].tolist())
            crash_ids = df[df['acc_inv'] == 1]['obj_id'].tolist() 
        crash_pred_frame_id = crash_frame_id - 1
        if t_prediction+sequence_dist+t_prediction <= crash_pred_frame_id:
            pred_frame_id_list = [crash_pred_frame_id-t_prediction-sequence_dist, crash_pred_frame_id]
        else:
            pred_frame_id_list = [t_prediction-1, crash_pred_frame_id]
        print(scene)
        pair_seq = []
        for pred_frame_id in pred_frame_id_list:
            for frame_id in range(pred_frame_id-t_prediction+1, pred_frame_id+1):
                df_frame = df[df['frame_id'] == frame_id]
                df_numeric = df_frame[['x_center', 'y_center', 'bbox_x', 'bbox_y', 'vel_x', 'vel_y']]
                # x_numeric = torch.tensor(df_numeric.to_numpy(), dtype=torch.float)
                df_numeric_norm = df_numeric / df_numeric.to_numpy().max() 
                id_list = df_frame['obj_id'].tolist()  # all node ids in predicted frame
                node_idx_list = list(range(len(id_list)))
                df_dummies = pd.get_dummies(df_frame[['obj_cls']].astype(pd.CategoricalDtype(categories=['car',
                                                                                            'van',
                                                                                            'truck',
                                                                                            'motorcycle',
                                                                                            'cyclist',
                                                                                            'pedestrian'
                                                                                            ])), dtype=float)
                df_features = pd.concat([df_dummies, df_numeric_norm], axis=1)
                node_features = df_features.to_numpy()
                edge_index = [[],[]]
                edge_features = []
                edge_id = []
                for node_connection in it.combinations(node_idx_list, 2):
                    x1 = df_numeric['x_center'].tolist()[node_connection[0]]
                    y1 = df_numeric['y_center'].tolist()[node_connection[0]]
                    v_x1 = df_numeric['vel_x'].tolist()[node_connection[0]]
                    v_y1 = df_numeric['vel_y'].tolist()[node_connection[0]]
                    x2 = df_numeric['x_center'].tolist()[node_connection[1]]
                    y2 = df_numeric['y_center'].tolist()[node_connection[1]]
                    v_x2 = df_numeric['vel_x'].tolist()[node_connection[1]]
                    v_y2 = df_numeric['vel_y'].tolist()[node_connection[1]]
                    delta_x = x2 - x1
                    delta_y = y2 - y1
                    delta_v_x = v_x1 - v_x2
                    delta_v_y = v_y1 - v_y2
                    if delta_v_x**2+delta_v_y**2 == 0:
                        min_d = math.sqrt(delta_x**2+delta_y**2)
                        t_accident = 0
                    else:
                        t_accident = (delta_x*delta_v_x+delta_y*delta_v_y)/(delta_v_x**2+delta_v_y**2)
                        if t_accident < 0:
                            min_d = math.sqrt(delta_x**2+delta_y**2)
                        else:
                            min_d = abs((delta_x*delta_v_y-delta_y*delta_v_x))/math.sqrt(delta_v_x**2+delta_v_y**2)
                    if min_d <= min_d_threshold and t_accident <= t_threshold:
                        edge_index[0].append(node_connection[0])
                        edge_index[0].append(node_connection[1])
                        edge_index[1].append(node_connection[1])
                        edge_index[1].append(node_connection[0])
                        edge_features.append([t_accident, min_d])
                        edge_features.append([t_accident, min_d])
                        edge_id.append([id_list[node_connection[0]], id_list[node_connection[1]]])
                        edge_id.append([id_list[node_connection[1]], id_list[node_connection[0]]])
                edge_features_norm = nn.functional.normalize(torch.tensor(edge_features, dtype=torch.float), p=1.0, dim = 0)
                if pred_frame_id_list.index(pred_frame_id) == 0:
                    y = torch.tensor([0], dtype=torch.long)
                else:
                    y = torch.tensor([1], dtype=torch.long)
                data = Data(edge_index = torch.tensor(edge_index, dtype=torch.long),
                            x = torch.tensor(node_features, dtype=torch.float),
                            edge_attr = edge_features_norm,
                            y = y,
                            frame_to_crash = torch.tensor(crash_frame_id-frame_id, dtype=torch.float),
                            # crash_node_idx = torch.tensor([crash_node_idx], dtype=torch.long)
                            obj_ids = torch.tensor(id_list, dtype=torch.long),
                            crash_ids = torch.tensor(crash_ids, dtype=torch.long)
                            )
                pair_seq.append(data)
        sub_class.append(pair_seq)
    group_train.append(sub_class)
# Out:
# train_09_Town05_type001_subtype0002_scenario00006.txt
# train_09_Town03_type001_subtype0002_scenario00027.txt
# Mini_ds_Town05_type001_subtype0001_scenario00007.txt
# train_01_Town10HD_type001_subtype0002_scenario00005.txt
# train_08_Town02_type001_subtype0001_scenario00009.txt
# train_04_Town04_type001_subtype0001_scenario00033.txt
# train_04_Town05_type001_subtype0001_scenario00007.txt
# train_09_Town05_type001_subtype0002_scenario00006.txt
# train_09_Town03_type001_subtype0002_scenario00027.txt
# Mini_ds_Town05_type001_subtype0001_scenario00007.txt
# train_01_Town10HD_type001_subtype0002_scenario00005.txt
# train_08_Town02_type001_subtype0001_scenario00009.txt
# train_04_Town04_type001_subtype0001_scenario00033.txt
# train_04_Town05_type001_subtype0001_scenario00007.txt
# train_09_Town05_type001_subtype0002_scenario00006.txt
# train_09_Town03_type001_subtype0002_scenario00027.txt
# Mini_ds_Town05_type001_subtype0001_scenario00007.txt
# train_01_Town10HD_type001_subtype0002_scenario00005.txt
# train_08_Town02_type001_subtype0001_scenario00009.txt
# train_04_Town04_type001_subtype0001_scenario00033.txt
# train_04_Town05_type001_subtype0001_scenario00007.txt
# train_09_Town05_type001_subtype0002_scenario00006.txt
# train_09_Town03_type001_subtype0002_scenario00027.txt
# Mini_ds_Town05_type001_subtype0001_scenario00007.txt
# train_01_Town10HD_type001_subtype0002_scenario00005.txt
# train_08_Town02_type001_subtype0001_scenario00009.txt
# train_04_Town04_type001_subtype0001_scenario00033.txt
# train_04_Town05_type001_subtype0001_scenario00007.txt
# train_09_Town05_type001_subtype0002_scenario00006.txt
# train_09_Town03_type001_subtype0002_scenario00027.txt
# Mini_ds_Town05_type001_subtype0001_scenario00007.txt
# train_01_Town10HD_type001_subtype0002_scenario00005.txt
# train_08_Town02_type001_subtype0001_scenario00009.txt
# train_04_Town04_type001_subtype0001_scenario00033.txt
# train_04_Town05_type001_subtype0001_scenario00007.txt
# train_09_Town05_type001_subtype0002_scenario00006.txt
# train_06_Town03_type001_subtype0002_scenario00021.txt
# train_08_Town04_type001_subtype0002_scenario00007.txt
# train_09_Town07_type001_subtype0002_scenario00022.txt
# train_02_Town10HD_type001_subtype0001_scenario00031.txt
# train_04_Town10HD_type001_subtype0001_scenario00029.txt
# Mini_ds_Town02_type001_subtype0001_scenario00013.txt
# train_02_Town03_type001_subtype0002_scenario00026.txt
# train_03_Town10HD_type001_subtype0002_scenario00014.txt
# train_04_Town03_type001_subtype0001_scenario00036.txt
# train_02_Town05_type001_subtype0001_scenario00012.txt
# train_04_Town02_type001_subtype0001_scenario00008.txt
# train_07_Town07_type001_subtype0001_scenario00015.txt
# train_03_Town04_type001_subtype0002_scenario00012.txt

# %%
dataset_test = []
# test_scene_list += normal_scene_list[ : len(test_scene_list)]
for scene in test_scene_list:
    if scene in normal_scene_list:
        # y = 0
        df = pd.read_csv(normal_dir+scene.replace('.txt','.csv'))  # read the i-th csv file
        crash_frame_id = df[-1:]['frame_id'].item()
        crash_ids = [314159, 314159]
    else:
        # y = 1
        df = pd.read_csv(accident_dir+scene.replace('.txt','.csv'))
        crash_frame_id = min(df[df['acc_inv'] == 1]['frame_id'].tolist())
        crash_ids = df[df['acc_inv'] == 1]['obj_id'].tolist() 
    crash_pred_frame_id = crash_frame_id - 1
    if t_prediction+sequence_dist+t_prediction <= crash_pred_frame_id:
        pred_frame_id_list = [crash_pred_frame_id-t_prediction-sequence_dist, crash_pred_frame_id]
    else:
        pred_frame_id_list = [t_prediction-1, crash_pred_frame_id]
    print(scene)
    for pred_frame_id in pred_frame_id_list:
        for frame_id in range(pred_frame_id-t_prediction+1, pred_frame_id+1):
            df_frame = df[df['frame_id'] == frame_id]
            df_numeric = df_frame[['x_center', 'y_center', 'bbox_x', 'bbox_y', 'vel_x', 'vel_y']]
            # x_numeric = torch.tensor(df_numeric.to_numpy(), dtype=torch.float)
            df_numeric_norm = df_numeric / df_numeric.to_numpy().max() 
            id_list = df_frame['obj_id'].tolist()  # all node ids in predicted frame
            node_idx_list = list(range(len(id_list)))
            df_dummies = pd.get_dummies(df_frame[['obj_cls']].astype(pd.CategoricalDtype(categories=['car',
                                                                                        'van',
                                                                                        'truck',
                                                                                        'motorcycle',
                                                                                        'cyclist',
                                                                                        'pedestrian'
                                                                                        ])), dtype=float)
            df_features = pd.concat([df_dummies, df_numeric_norm], axis=1)
            node_features = df_features.to_numpy()
            edge_index = [[],[]]
            edge_features = []
            edge_id = []
            for node_connection in it.combinations(node_idx_list, 2):
                x1 = df_numeric['x_center'].tolist()[node_connection[0]]
                y1 = df_numeric['y_center'].tolist()[node_connection[0]]
                v_x1 = df_numeric['vel_x'].tolist()[node_connection[0]]
                v_y1 = df_numeric['vel_y'].tolist()[node_connection[0]]
                x2 = df_numeric['x_center'].tolist()[node_connection[1]]
                y2 = df_numeric['y_center'].tolist()[node_connection[1]]
                v_x2 = df_numeric['vel_x'].tolist()[node_connection[1]]
                v_y2 = df_numeric['vel_y'].tolist()[node_connection[1]]
                delta_x = x2 - x1
                delta_y = y2 - y1
                delta_v_x = v_x1 - v_x2
                delta_v_y = v_y1 - v_y2
                if delta_v_x**2+delta_v_y**2 == 0:
                    min_d = math.sqrt(delta_x**2+delta_y**2)
                    t_accident = 0
                else:
                    t_accident = (delta_x*delta_v_x+delta_y*delta_v_y)/(delta_v_x**2+delta_v_y**2)
                    if t_accident < 0:
                        min_d = math.sqrt(delta_x**2+delta_y**2)
                    else:
                        min_d = abs((delta_x*delta_v_y-delta_y*delta_v_x))/math.sqrt(delta_v_x**2+delta_v_y**2)
                if min_d <= min_d_threshold and t_accident <= t_threshold:
                    edge_index[0].append(node_connection[0])
                    edge_index[0].append(node_connection[1])
                    edge_index[1].append(node_connection[1])
                    edge_index[1].append(node_connection[0])
                    edge_features.append([t_accident, min_d])
                    edge_features.append([t_accident, min_d])
                    edge_id.append([id_list[node_connection[0]], id_list[node_connection[1]]])
                    edge_id.append([id_list[node_connection[1]], id_list[node_connection[0]]])
            edge_features_norm = nn.functional.normalize(torch.tensor(edge_features, dtype=torch.float), p=1.0, dim = 0)
            if pred_frame_id_list.index(pred_frame_id) == 0:
                y = torch.tensor([0], dtype=torch.long)
            else:
                y = torch.tensor([1], dtype=torch.long)
            data = Data(edge_index = torch.tensor(edge_index, dtype=torch.long),
                        x = torch.tensor(node_features, dtype=torch.float),
                        edge_attr = edge_features_norm,
                        y = y,
                        frame_to_crash = torch.tensor(crash_frame_id-frame_id, dtype=torch.float),
                        # crash_node_idx = torch.tensor([crash_node_idx], dtype=torch.long)
                        obj_ids = torch.tensor(id_list, dtype=torch.long),
                        crash_ids = torch.tensor(crash_ids, dtype=torch.long)
                        )
            dataset_test.append(data)
# Out:
# val_01_Town03_type001_subtype0002_scenario00030.txt
# train_09_Town03_type001_subtype0001_scenario00014.txt
# train_01_Town05_type001_subtype0002_scenario00019.txt
# train_04_Town07_type001_subtype0001_scenario00010.txt
# train_01_Town05_type001_subtype0002_scenario00012.txt
# train_03_Town05_type001_subtype0001_scenario00020.txt
# train_06_Town04_type001_subtype0002_scenario00022.txt
# val_01_Town04_type001_subtype0002_scenario00025.txt
# train_06_Town05_type001_subtype0002_scenario00002.txt
# train_03_Town03_type001_subtype0001_scenario00015.txt
# train_05_Town05_type001_subtype0001_scenario00005.txt
# train_05_Town03_type001_subtype0002_scenario00010.txt
# train_02_Town10HD_type001_subtype0001_scenario00021.txt
# train_09_Town04_type001_subtype0001_scenario00013.txt
# val_01_Town10HD_type001_subtype0001_scenario00020.txt
# train_10_Town07_type001_subtype0001_scenario00019.txt
# train_04_Town05_type001_subtype0002_scenario00028.txt
# train_07_Town04_type001_subtype0001_scenario00005.txt
# train_03_Town03_type001_subtype0001_scenario00024.txt
# val_02_Town04_type001_subtype0001_scenario00036.txt
# train_07_Town04_type001_subtype0001_scenario00031.txt
# train_07_Town02_type001_subtype0001_scenario00011.txt
# train_06_Town05_type001_subtype0001_scenario00034.txt
# train_08_Town07_type001_subtype0002_scenario00017.txt
# val_01_Town10HD_type001_subtype0001_scenario00035.txt
# val_02_Town04_type001_subtype0001_scenario00038.txt
# train_02_Town05_type001_subtype0001_scenario00029.txt
# train_06_Town05_type001_subtype0001_scenario00018.txt
# train_03_Town04_type001_subtype0002_scenario00018.txt
# val_01_Town05_type001_subtype0002_scenario00004.txt
# train_04_Town03_type001_subtype0001_scenario00017.txt
# val_02_Town05_type001_subtype0001_scenario00025.txt
# val_02_Town07_type001_subtype0002_scenario00001.txt
# train_01_Town03_type001_subtype0002_scenario00013.txt
# train_06_Town04_type001_subtype0001_scenario00018.txt

# %%
# create a list to store all .csv files
train_scene_dir_list = ['../csv_data/train/accident/', '../csv_data/train/normal/']
dataset_train = []
for train_scene_dir in train_scene_dir_list:
  all_scenes = []
  for filename in os.listdir(train_scene_dir):
      if filename.endswith('csv'):
          all_scenes.append(filename)
  for scene in all_scenes:
    df = pd.read_csv(train_scene_dir+scene)
    frame_id_list = list(set(df['frame_id'].tolist()))
    if train_scene_dir == '../csv_data/train/accident/':
      crash_frame_id = min(df[df['acc_inv'] == 1]['frame_id'].tolist())
      crash_ids = df[df['acc_inv'] == 1]['obj_id'].tolist()
    else:
      crash_frame_id = max(frame_id_list)
      crash_ids = [314159, 314159]
    for frame_id in frame_id_list:
      df_frame = df[df['frame_id'] == frame_id]
      df_dummies = pd.get_dummies(df_frame[['obj_cls']].astype(pd.CategoricalDtype(categories=['car',
                                                                                               'van',
                                                                                               'truck',
                                                                                               'motorcycle',
                                                                                               'cyclist',
                                                                                               'pedestrian'])), dtype=float)
      df_numeric = df_frame[['x_center', 'y_center', 'bbox_x', 'bbox_y', 'vel_x', 'vel_y']]
      normalized_df_numeric=(df_numeric - df_numeric.mean()) / df_numeric.std()
      df_features = pd.concat([df_dummies, normalized_df_numeric], axis=1)
      node_features = df_features.to_numpy()
      node_idx_list = list(range(node_features.shape[0]))
      edge_index = [[],[]]
      edge_features = []
      for node_connection in it.combinations(node_idx_list, 2):
        x1 = df_numeric['x_center'].tolist()[node_connection[0]]
        y1 = df_numeric['y_center'].tolist()[node_connection[0]]
        v_x1 = df_numeric['vel_x'].tolist()[node_connection[0]]
        v_y1 = df_numeric['vel_y'].tolist()[node_connection[0]]
        x2 = df_numeric['x_center'].tolist()[node_connection[1]]
        y2 = df_numeric['y_center'].tolist()[node_connection[1]]
        v_x2 = df_numeric['vel_x'].tolist()[node_connection[1]]
        v_y2 = df_numeric['vel_y'].tolist()[node_connection[1]]
        delta_x = x2 - x1
        delta_y = y2 - y1
        delta_v_x = v_x2 - v_x1
        delta_v_y = v_y2 - v_y1
        if delta_v_x**2+delta_v_y**2 == 0:
          min_d = math.sqrt(delta_x**2+delta_y**2)
          t_accident = -1
        else:
          min_d = abs((delta_x*delta_v_y-delta_y*delta_v_x)/math.sqrt(delta_v_x**2+delta_v_y**2)) # absolute distance of smallest distance
          t_accident = (delta_x*delta_v_x+delta_y*delta_v_y)/(delta_v_x**2+delta_v_y**2) # if t_accident is negative, they will never crash.
        if min_d < min_d_threshold and t_accident < t_threshold and t_accident > 0:
          edge_index[0].append(node_connection[0])
          edge_index[0].append(node_connection[1])
          edge_index[1].append(node_connection[1])
          edge_index[1].append(node_connection[0])
          edge_features.append([delta_v_x/delta_x, delta_v_y/delta_y])
          edge_features.append([delta_v_x/delta_x, delta_v_y/delta_y])
      edge_features_norm = nn.functional.normalize(torch.tensor(edge_features, dtype=torch.float), p=1.0, dim = 0)

      obj_id_list = df_frame['obj_id'].to_list()

      if len(edge_index[0]) != 0:
        if frame_id >= crash_frame_id - t_prediction or frame_id < crash_frame_id - t_prediction - 30:
          if crash_ids[0] in obj_id_list and crash_ids[1] in obj_id_list:
            y = torch.tensor([1], dtype=torch.long)
          else:
            y = torch.tensor([0], dtype=torch.long)
          data = Data(edge_index = torch.tensor(edge_index, dtype=torch.long),
                      x = torch.tensor(node_features, dtype=torch.float),
                      edge_attr = edge_features_norm,
                      y = y,
                      frame_to_crash = torch.tensor(crash_frame_id-frame_id, dtype=torch.float),
                      # crash_node_idx = torch.tensor([crash_node_idx], dtype=torch.long)
                      obj_ids = torch.tensor(obj_id_list, dtype=torch.long),
                      crash_ids = torch.tensor(crash_ids, dtype=torch.long)
                      )
          dataset_train.append(data)
    print(round(all_scenes.index(scene)/len(all_scenes), 2)*100, '% done.')
    clear_output(wait=True)
print('training dataset completed!')

############################################################################################################################
# test dataset
test_scene_dir_list = ['../csv_data/test/accident/', '../csv_data/test/normal/']
dataset_test = []
for train_scene_dir in test_scene_dir_list:
  all_scenes = []
  for filename in os.listdir(train_scene_dir):
      if filename.endswith('csv'):
          all_scenes.append(filename)
  for scene in all_scenes:
    df = pd.read_csv(train_scene_dir+scene)
    frame_id_list = list(set(df['frame_id'].tolist()))
    if train_scene_dir == '../csv_data/test/accident/':
      crash_frame_id = min(df[df['acc_inv'] == 1]['frame_id'].tolist())
      crash_ids = df[df['acc_inv'] == 1]['obj_id'].tolist()
    else:
      crash_frame_id = max(frame_id_list)
      crash_ids = [314159, 314159]
    for frame_id in frame_id_list:
      df_frame = df[df['frame_id'] == frame_id]
      df_dummies = pd.get_dummies(df_frame[['obj_cls']].astype(pd.CategoricalDtype(categories=['car',
                                                                                               'van',
                                                                                               'truck',
                                                                                               'motorcycle',
                                                                                               'cyclist',
                                                                                               'pedestrian'])), dtype=float)
      df_numeric = df_frame[['x_center', 'y_center', 'bbox_x', 'bbox_y', 'vel_x', 'vel_y']]
      normalized_df_numeric=(df_numeric - df_numeric.mean()) / df_numeric.std()
      df_features = pd.concat([df_dummies, normalized_df_numeric], axis=1)
      node_features = df_features.to_numpy()
      node_idx_list = list(range(node_features.shape[0]))
      edge_index = [[],[]]
      edge_features = []
      for node_connection in it.combinations(node_idx_list, 2):
        x1 = df_numeric['x_center'].tolist()[node_connection[0]]
        y1 = df_numeric['y_center'].tolist()[node_connection[0]]
        v_x1 = df_numeric['vel_x'].tolist()[node_connection[0]]
        v_y1 = df_numeric['vel_y'].tolist()[node_connection[0]]
        x2 = df_numeric['x_center'].tolist()[node_connection[1]]
        y2 = df_numeric['y_center'].tolist()[node_connection[1]]
        v_x2 = df_numeric['vel_x'].tolist()[node_connection[1]]
        v_y2 = df_numeric['vel_y'].tolist()[node_connection[1]]
        delta_x = x2 - x1
        delta_y = y2 - y1
        delta_v_x = v_x2 - v_x1
        delta_v_y = v_y2 - v_y1
        if delta_v_x**2+delta_v_y**2 == 0:
          min_d = math.sqrt(delta_x**2+delta_y**2)
          t_accident = -1
        else:
          min_d = abs((delta_x*delta_v_y-delta_y*delta_v_x)/math.sqrt(delta_v_x**2+delta_v_y**2)) # absolute distance of smallest distance
          t_accident = (delta_x*delta_v_x+delta_y*delta_v_y)/(delta_v_x**2+delta_v_y**2) # if t_accident is negative, they will never crash.
        if min_d < min_d_threshold and t_accident < t_threshold and t_accident > 0:
          edge_index[0].append(node_connection[0])
          edge_index[0].append(node_connection[1])
          edge_index[1].append(node_connection[1])
          edge_index[1].append(node_connection[0])
          edge_features.append([delta_v_x/delta_x, delta_v_y/delta_y])
          edge_features.append([delta_v_x/delta_x, delta_v_y/delta_y])
      edge_features_norm = nn.functional.normalize(torch.tensor(edge_features, dtype=torch.float), p=1.0, dim = 0)

      obj_id_list = df_frame['obj_id'].to_list()

      if len(edge_index[0]) != 0:
        if frame_id >= crash_frame_id - t_prediction or frame_id < crash_frame_id - t_prediction - 30:
          if crash_ids[0] in obj_id_list and crash_ids[1] in obj_id_list:
            y = torch.tensor([1], dtype=torch.long)
          else:
            y = torch.tensor([0], dtype=torch.long)
          data = Data(edge_index = torch.tensor(edge_index, dtype=torch.long),
                      x = torch.tensor(node_features, dtype=torch.float),
                      edge_attr = edge_features_norm,
                      y = y,
                      frame_to_crash = torch.tensor(crash_frame_id-frame_id, dtype=torch.float),
                      # crash_node_idx = torch.tensor([crash_node_idx], dtype=torch.long)
                      obj_ids = torch.tensor(obj_id_list, dtype=torch.long),
                      crash_ids = torch.tensor(crash_ids, dtype=torch.long)
                      )
          dataset_test.append(data)
    print(round(all_scenes.index(scene)/len(all_scenes), 2)*100, '% done.')
    clear_output(wait=True)
print('testing dataset completed!')
# Out:
# testing dataset completed!

# %% [markdown]
# ### Classifier Training

# %%
args = {
    "device" : torch.device("cuda:3" if torch.cuda.is_available() else "cpu"),
    "save" : "Single_Graph_BC_Reg_model",
    "load" : "ssl_model",
    "lr" : 0.0003,
    "lr_reg" : 0.00001,
    "epochs" : 200,
    "batch_size" : 64,
    "num_workers" : 2,
    "model" : "gat", # choices are ["gcn", "gin", "resgcn", "gat", "graphsage", "sgc"]
    "input_dim" : 12, # input dimension for node features
    # "num_classes" : len(all_names), # collision
    "num_classes" : 1,
    "feat_dim" : 8,
    "layers" : 3,
    "train_data_percent" : 0.8,
}

class AttributeDict(dict):
    def __init__(self, *args, **kwargs):
        super(AttributeDict, self).__init__(*args, **kwargs)
        self.__dict__ = self

args = AttributeDict(args)

# %%
# train_dataset = dataset_train
grouped_train_dataset = group_train
val_dataset = dataset_test
test_dataset = dataset_test
# train_loader = DataLoader(train_dataset, num_workers=args.num_workers, batch_size=args.batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, num_workers=args.num_workers, batch_size=args.batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, num_workers=args.num_workers, batch_size=args.batch_size, shuffle=True)

# print("Dataset split: {} {} {}".format(len(train_dataset), len(val_dataset), len(val_dataset)))
print("Number of classes: {}".format(args.num_classes))
# Out:
# Number of classes: 1

# %%
import importlib, models_Single_Graph_BC_Reg
importlib.reload(models_Single_Graph_BC_Reg)
from models_Single_Graph_BC_Reg import *

# classification model is a GNN encoder followed by linear layer
model = GraphClassificationModel(args.input_dim, args.feat_dim, n_layers=args.layers, gnn=args.model, output_dim=args.num_classes
                                # , load=args.load
                                 )

for param in model.parameters():
    param.requires_grad = True

model = model.to(args.device)

optimizer = torch.optim.Adam(model.parameters(), lr=args.lr)
optimizer_reg = torch.optim.Adam(model.parameters(), lr=args.lr_reg)

# %%
model.train()
loss_fn = torch.nn.BCEWithLogitsLoss()
loss_mse = torch.nn.MSELoss()

best_train_loss, best_val_loss = float("inf"), float("inf")
is_best_loss = False
best_val_acc = 0
for epoch in range(args.epochs):
    losses = []
    edge_losses = []
    reg_losses = []
    correct = 0
    edge_correct = 0
    frame_error = 0

    for acc_type in grouped_train_dataset:
        random.shuffle(acc_type)
    train_dataset = []
    for i in range(major_acc_num):
        for acc_type in grouped_train_dataset:
            train_dataset += acc_type[i]
    flattened = train_dataset   # (15+15)*36*8
    train_loader = DataLoader(flattened, num_workers=args.num_workers, batch_size=(15+15)*8, shuffle=False)

    for data in train_loader:
        data.to(args.device)
        data_input = data.x, data.edge_index, data.batch, data.edge_attr
        labels = data.y
        
        regression_score = model(data_input)[1][data.y == 1]
        regression_gt = data.frame_to_crash[data.y == 1]
        loss_reg = torch.sqrt(loss_mse(torch.flatten(regression_score, start_dim=0), regression_gt))/(t_prediction*10)
        frame_error += abs(torch.sub(torch.flatten(regression_score, start_dim=0), regression_gt)).sum().item() / regression_gt.size(0)
        reg_losses.append(loss_reg.item())
        optimizer.zero_grad()
        loss_reg.backward()
        optimizer.step()

        gt = labels.float()
        scores = model(data_input)[0].squeeze(1)
        loss = loss_fn(scores, gt)
        pred = []
        for pr in scores:
            if torch.sigmoid(pr)>0.5:
                pred.append(1)
            else:
                pred.append(0)
        correct += int((torch.tensor(pred).to(args.device) == gt).sum()) / gt.size(0)
        losses.append(loss.item())

        # backprop
        optimizer.zero_grad()
        # (loss+loss_reg).backward()
        loss.backward()
        # loss_edge.backward()
        # loss_reg.backward()
        optimizer.step()


    epoch_loss_train = sum(losses) / len(losses)
    # epoch_edge_loss_train = sum(edge_losses) / len(edge_losses)
    epoch_reg_loss_train = sum(reg_losses) / len(reg_losses)
    epoch_acc_train = correct / len(train_loader)
    # epoch_edge_acc_train = edge_correct / len(train_loader)
    epoch_reg_error_train = frame_error / len(train_loader)


    # validation
    losses = []
    edge_losses = []
    reg_losses = []
    correct = 0
    edge_correct = 0
    frame_error = 0

    for data in val_loader:
        data.to(args.device)
        data_input = data.x, data.edge_index, data.batch, data.edge_attr
        labels = data.y
        gt = labels.float()
        scores = model(data_input)[0].squeeze(1)
        loss = loss_fn(scores, gt)
        pred = []
        for pr in scores:
            if torch.sigmoid(pr)>0.5:
                pred.append(1)
            else:
                pred.append(0)
        correct += int((torch.tensor(pred).to(args.device) == gt).sum()) / gt.size(0)
        losses.append(loss.item())
        regression_score = model(data_input)[1][data.y == 1]
        regression_gt = data.frame_to_crash[data.y == 1]
        loss_reg = torch.sqrt(loss_mse(torch.flatten(regression_score, start_dim=0), regression_gt))/(t_prediction*10)
        frame_error += abs(torch.sub(torch.flatten(regression_score, start_dim=0), regression_gt)).sum().item() / regression_gt.size(0)
        reg_losses.append(loss_reg.item())


    # gather the results for the epoch
    epoch_loss_val = sum(losses) / len(losses)
    epoch_acc_val = correct / len(val_loader)
    # epoch_edge_loss_val = sum(edge_losses) / len(edge_losses)
    # epoch_edge_acc_val = edge_correct / len(val_loader)
    epoch_reg_loss_val = sum(reg_losses) / len(reg_losses)
    epoch_reg_error_val = frame_error / len(val_loader)


    log = "Epoch {},   Train Loss: {:.3f},            Train Accuracy: {:.3f},            Val Loss: {:.3f}, Val Accuracy: {:.3f}, \nTrain Regression Loss: {:.3f}, Train Regression Error: {:.3f}, Val Regression Loss: {:.3f}, Val Regression Error: {:.3f}\n"
    print(log.format(epoch, 
                     epoch_loss_train, epoch_acc_train, epoch_loss_val, epoch_acc_val, 
                     epoch_reg_loss_train, epoch_reg_error_train, epoch_reg_loss_val, epoch_reg_error_val))

    # log = "Epoch {},   Train Loss: {:.3f},            Train Accuracy: {:.3f},            Val Loss: {:.3f}, Val Accuracy: {:.3f}, \n      Train Edge Loss: {:.3f},       Train Edge Accuracy: {:.3f},       Val Edge Loss: {:.3f}, Val Edge Accuracy: {:.3f},\nTrain Regression Loss: {:.3f}, Train Regression Accuracy: {:.3f}, Val Regression Loss: {:.3f}, Val Regression Accuracy: {:.3f}\n"
    # print(log.format(epoch, 
    #                  epoch_loss_train, epoch_acc_train, epoch_loss_val, epoch_acc_val, 
    #                  epoch_edge_loss_train, epoch_edge_acc_train, epoch_edge_loss_val, epoch_edge_acc_val,
    #                  epoch_reg_loss_train, epoch_reg_error_train, epoch_reg_loss_val, epoch_reg_error_val))

    if epoch_acc_val > best_val_acc:
        best_epoch, best_train_graph_loss, best_val_loss, is_best_loss = epoch, epoch_reg_loss_train, epoch_reg_loss_val, True
        best_train_acc, best_val_acc = epoch_acc_train, epoch_acc_val

# model.save_checkpoint(os.path.join("logs", args.save), optimizer, epoch, best_train_graph_loss, best_val_loss, is_best_loss)
print('best Epoch: ', best_epoch, ', best total train loss: ', best_train_graph_loss, ', best total val loss: ', best_val_loss)
print('graph classification train acc: ', epoch_acc_train, 'graph classification val acc: ', epoch_acc_val)
# print('edge classification train acc: ', epoch_edge_acc_train, 'edge classification val acc: ', epoch_edge_acc_val)
print('regression train error: ', epoch_reg_error_train, 'regression test error: ', epoch_reg_error_val)
# Out:
# Epoch 0,   Train Loss: 0.699,            Train Accuracy: 0.520,            Val Loss: 0.689, Val Accuracy: 0.526,
# Train Regression Loss: 0.059, Train Regression Error: 7.717, Val Regression Loss: 0.048, Val Regression Error: 5.998
#
# Epoch 1,   Train Loss: 0.681,            Train Accuracy: 0.575,            Val Loss: 0.680, Val Accuracy: 0.579,
# Train Regression Loss: 0.042, Train Regression Error: 5.219, Val Regression Loss: 0.034, Val Regression Error: 4.285
#
# Epoch 2,   Train Loss: 0.672,            Train Accuracy: 0.577,            Val Loss: 0.685, Val Accuracy: 0.529,
# Train Regression Loss: 0.035, Train Regression Error: 4.315, Val Regression Loss: 0.033, Val Regression Error: 4.155
#
# Epoch 3,   Train Loss: 0.662,            Train Accuracy: 0.604,            Val Loss: 0.679, Val Accuracy: 0.551,
# Train Regression Loss: 0.030, Train Regression Error: 3.882, Val Regression Loss: 0.030, Val Regression Error: 3.889
#
# Epoch 56,   Train Loss: 0.427,            Train Accuracy: 0.775,            Val Loss: 0.603, Val Accuracy: 0.656,
# Train Regression Loss: 0.030, Train Regression Error: 3.872, Val Regression Loss: 0.030, Val Regression Error: 3.875
#
# Epoch 57,   Train Loss: 0.428,            Train Accuracy: 0.774,            Val Loss: 0.592, Val Accuracy: 0.687,
# Train Regression Loss: 0.030, Train Regression Error: 3.866, Val Regression Loss: 0.030, Val Regression Error: 3.868
#
# Epoch 58,   Train Loss: 0.426,            Train Accuracy: 0.767,            Val Loss: 0.595, Val Accuracy: 0.685,
# Train Regression Loss: 0.030, Train Regression Error: 3.862, Val Regression Loss: 0.030, Val Regression Error: 3.861
#
# Epoch 59,   Train Loss: 0.421,            Train Accuracy: 0.778,            Val Loss: 0.588, Val Accuracy: 0.681,
# Train Regression Loss: 0.030, Train Regression Error: 3.858, Val Regression Loss: 0.030, Val Regression Error: 3.837
#
# Epoch 60,   Train Loss: 0.425,            Train Accuracy: 0.777,            Val Loss: 0.618, Val Accuracy: 0.653,
# Train Regression Loss: 0.030, Train Regression Error: 3.853, Val Regression Loss: 0.030, Val Regression Error: 3.833
#
# Epoch 61,   Train Loss: 0.417,            Train Accuracy: 0.773,            Val Loss: 0.640, Val Accuracy: 0.658,
# Train Regression Loss: 0.030, Train Regression Error: 3.846, Val Regression Loss: 0.030, Val Regression Error: 3.890
#
# Epoch 62,   Train Loss: 0.422,            Train Accuracy: 0.776,            Val Loss: 0.596, Val Accuracy: 0.658,
# Train Regression Loss: 0.030, Train Regression Error: 3.841, Val Regression Loss: 0.030, Val Regression Error: 3.912
#
# Epoch 63,   Train Loss: 0.419,            Train Accuracy: 0.779,            Val Loss: 0.606, Val Accuracy: 0.670,
# Train Regression Loss: 0.030, Train Regression Error: 3.838, Val Regression Loss: 0.030, Val Regression Error: 3.847
#
# Epoch 64,   Train Loss: 0.411,            Train Accuracy: 0.782,            Val Loss: 0.620, Val Accuracy: 0.668,
# Train Regression Loss: 0.030, Train Regression Error: 3.830, Val Regression Loss: 0.029, Val Regression Error: 3.783
#
# Epoch 65,   Train Loss: 0.401,            Train Accuracy: 0.794,            Val Loss: 0.602, Val Accuracy: 0.669,
# Train Regression Loss: 0.030, Train Regression Error: 3.826, Val Regression Loss: 0.030, Val Regression Error: 3.823
#
# Epoch 66,   Train Loss: 0.405,            Train Accuracy: 0.786,            Val Loss: 0.590, Val Accuracy: 0.700,
# Train Regression Loss: 0.030, Train Regression Error: 3.820, Val Regression Loss: 0.030, Val Regression Error: 3.842
#
# Epoch 67,   Train Loss: 0.396,            Train Accuracy: 0.788,            Val Loss: 0.591, Val Accuracy: 0.694,
# Train Regression Loss: 0.030, Train Regression Error: 3.820, Val Regression Loss: 0.030, Val Regression Error: 3.878
#
# Epoch 68,   Train Loss: 0.399,            Train Accuracy: 0.789,            Val Loss: 0.644, Val Accuracy: 0.675,
# Train Regression Loss: 0.030, Train Regression Error: 3.812, Val Regression Loss: 0.030, Val Regression Error: 3.911
#
# Epoch 69,   Train Loss: 0.408,            Train Accuracy: 0.782,            Val Loss: 0.624, Val Accuracy: 0.664,
# Train Regression Loss: 0.030, Train Regression Error: 3.805, Val Regression Loss: 0.029, Val Regression Error: 3.792
#
# Epoch 70,   Train Loss: 0.395,            Train Accuracy: 0.791,            Val Loss: 0.590, Val Accuracy: 0.686,
# Train Regression Loss: 0.030, Train Regression Error: 3.800, Val Regression Loss: 0.030, Val Regression Error: 3.834
#
# Epoch 71,   Train Loss: 0.394,            Train Accuracy: 0.791,            Val Loss: 0.601, Val Accuracy: 0.671,
# Train Regression Loss: 0.030, Train Regression Error: 3.797, Val Regression Loss: 0.030, Val Regression Error: 3.808
#
# Epoch 72,   Train Loss: 0.396,            Train Accuracy: 0.791,            Val Loss: 0.624, Val Accuracy: 0.680,
# Train Regression Loss: 0.030, Train Regression Error: 3.789, Val Regression Loss: 0.030, Val Regression Error: 3.841
#
# Epoch 73,   Train Loss: 0.396,            Train Accuracy: 0.792,            Val Loss: 0.622, Val Accuracy: 0.680,
# Train Regression Loss: 0.030, Train Regression Error: 3.787, Val Regression Loss: 0.029, Val Regression Error: 3.769
#
# Epoch 74,   Train Loss: 0.396,            Train Accuracy: 0.781,            Val Loss: 0.588, Val Accuracy: 0.673,
# Train Regression Loss: 0.029, Train Regression Error: 3.782, Val Regression Loss: 0.030, Val Regression Error: 3.844
#
# Epoch 75,   Train Loss: 0.377,            Train Accuracy: 0.805,            Val Loss: 0.601, Val Accuracy: 0.684,
# Train Regression Loss: 0.029, Train Regression Error: 3.776, Val Regression Loss: 0.030, Val Regression Error: 3.810
#
# Epoch 76,   Train Loss: 0.386,            Train Accuracy: 0.793,            Val Loss: 0.626, Val Accuracy: 0.674,
# Train Regression Loss: 0.029, Train Regression Error: 3.773, Val Regression Loss: 0.030, Val Regression Error: 3.815
#
# Epoch 77,   Train Loss: 0.382,            Train Accuracy: 0.796,            Val Loss: 0.615, Val Accuracy: 0.675,
# Train Regression Loss: 0.029, Train Regression Error: 3.768, Val Regression Loss: 0.030, Val Regression Error: 3.843
#
# Epoch 78,   Train Loss: 0.379,            Train Accuracy: 0.798,            Val Loss: 0.597, Val Accuracy: 0.678,
# Train Regression Loss: 0.029, Train Regression Error: 3.763, Val Regression Loss: 0.030, Val Regression Error: 3.815
#
# Epoch 79,   Train Loss: 0.381,            Train Accuracy: 0.795,            Val Loss: 0.619, Val Accuracy: 0.675,
# Train Regression Loss: 0.029, Train Regression Error: 3.766, Val Regression Loss: 0.029, Val Regression Error: 3.797
#
# Epoch 80,   Train Loss: 0.379,            Train Accuracy: 0.797,            Val Loss: 0.594, Val Accuracy: 0.674,
# Train Regression Loss: 0.029, Train Regression Error: 3.758, Val Regression Loss: 0.029, Val Regression Error: 3.806
#
# Epoch 81,   Train Loss: 0.376,            Train Accuracy: 0.794,            Val Loss: 0.613, Val Accuracy: 0.673,
# Train Regression Loss: 0.028, Train Regression Error: 3.667, Val Regression Loss: 0.029, Val Regression Error: 3.747
#
# Epoch 108,   Train Loss: 0.330,            Train Accuracy: 0.819,            Val Loss: 0.679, Val Accuracy: 0.658,
# Train Regression Loss: 0.028, Train Regression Error: 3.667, Val Regression Loss: 0.029, Val Regression Error: 3.794
#
# Epoch 109,   Train Loss: 0.326,            Train Accuracy: 0.830,            Val Loss: 0.631, Val Accuracy: 0.687,
# Train Regression Loss: 0.028, Train Regression Error: 3.662, Val Regression Loss: 0.029, Val Regression Error: 3.754
#
# Epoch 110,   Train Loss: 0.328,            Train Accuracy: 0.821,            Val Loss: 0.671, Val Accuracy: 0.679,
# Train Regression Loss: 0.028, Train Regression Error: 3.659, Val Regression Loss: 0.029, Val Regression Error: 3.754
#
# Epoch 111,   Train Loss: 0.320,            Train Accuracy: 0.834,            Val Loss: 0.657, Val Accuracy: 0.680,
# Train Regression Loss: 0.028, Train Regression Error: 3.658, Val Regression Loss: 0.029, Val Regression Error: 3.722
#
# Epoch 112,   Train Loss: 0.322,            Train Accuracy: 0.828,            Val Loss: 0.674, Val Accuracy: 0.681,
# Train Regression Loss: 0.028, Train Regression Error: 3.655, Val Regression Loss: 0.029, Val Regression Error: 3.712
#
# Epoch 113,   Train Loss: 0.316,            Train Accuracy: 0.833,            Val Loss: 0.643, Val Accuracy: 0.685,
# Train Regression Loss: 0.028, Train Regression Error: 3.653, Val Regression Loss: 0.029, Val Regression Error: 3.789
#
# Epoch 114,   Train Loss: 0.320,            Train Accuracy: 0.825,            Val Loss: 0.642, Val Accuracy: 0.691,
# Train Regression Loss: 0.028, Train Regression Error: 3.652, Val Regression Loss: 0.029, Val Regression Error: 3.788
#
# Epoch 115,   Train Loss: 0.315,            Train Accuracy: 0.828,            Val Loss: 0.665, Val Accuracy: 0.682,
# Train Regression Loss: 0.028, Train Regression Error: 3.648, Val Regression Loss: 0.029, Val Regression Error: 3.757
#
# Epoch 116,   Train Loss: 0.315,            Train Accuracy: 0.834,            Val Loss: 0.631, Val Accuracy: 0.704,
# Train Regression Loss: 0.028, Train Regression Error: 3.646, Val Regression Loss: 0.029, Val Regression Error: 3.739
#
# Epoch 117,   Train Loss: 0.318,            Train Accuracy: 0.834,            Val Loss: 0.672, Val Accuracy: 0.692,
# Train Regression Loss: 0.028, Train Regression Error: 3.647, Val Regression Loss: 0.029, Val Regression Error: 3.759
#
# Epoch 118,   Train Loss: 0.322,            Train Accuracy: 0.826,            Val Loss: 0.645, Val Accuracy: 0.686,
# Train Regression Loss: 0.028, Train Regression Error: 3.644, Val Regression Loss: 0.029, Val Regression Error: 3.707
#
# Epoch 119,   Train Loss: 0.318,            Train Accuracy: 0.826,            Val Loss: 0.664, Val Accuracy: 0.702,
# Train Regression Loss: 0.028, Train Regression Error: 3.641, Val Regression Loss: 0.029, Val Regression Error: 3.745
#
# Epoch 120,   Train Loss: 0.314,            Train Accuracy: 0.825,            Val Loss: 0.680, Val Accuracy: 0.694,
# Train Regression Loss: 0.028, Train Regression Error: 3.612, Val Regression Loss: 0.029, Val Regression Error: 3.731
#
# Epoch 134,   Train Loss: 0.297,            Train Accuracy: 0.843,            Val Loss: 0.714, Val Accuracy: 0.698,
# Train Regression Loss: 0.028, Train Regression Error: 3.612, Val Regression Loss: 0.029, Val Regression Error: 3.769
#
# Epoch 135,   Train Loss: 0.290,            Train Accuracy: 0.844,            Val Loss: 0.670, Val Accuracy: 0.702,
# Train Regression Loss: 0.028, Train Regression Error: 3.610, Val Regression Loss: 0.029, Val Regression Error: 3.762
#
# Epoch 136,   Train Loss: 0.281,            Train Accuracy: 0.851,            Val Loss: 0.692, Val Accuracy: 0.698,
# Train Regression Loss: 0.028, Train Regression Error: 3.608, Val Regression Loss: 0.029, Val Regression Error: 3.805
#
# Epoch 137,   Train Loss: 0.284,            Train Accuracy: 0.854,            Val Loss: 0.708, Val Accuracy: 0.689,
# Train Regression Loss: 0.028, Train Regression Error: 3.606, Val Regression Loss: 0.029, Val Regression Error: 3.809
#
# Epoch 138,   Train Loss: 0.290,            Train Accuracy: 0.836,            Val Loss: 0.742, Val Accuracy: 0.680,
# Train Regression Loss: 0.028, Train Regression Error: 3.604, Val Regression Loss: 0.029, Val Regression Error: 3.735
#
# Epoch 139,   Train Loss: 0.277,            Train Accuracy: 0.855,            Val Loss: 0.659, Val Accuracy: 0.691,
# Train Regression Loss: 0.028, Train Regression Error: 3.603, Val Regression Loss: 0.029, Val Regression Error: 3.766
#
# Epoch 140,   Train Loss: 0.290,            Train Accuracy: 0.839,            Val Loss: 0.805, Val Accuracy: 0.687,
# Train Regression Loss: 0.028, Train Regression Error: 3.600, Val Regression Loss: 0.029, Val Regression Error: 3.776
#
# Epoch 141,   Train Loss: 0.293,            Train Accuracy: 0.844,            Val Loss: 0.716, Val Accuracy: 0.683,
# Train Regression Loss: 0.028, Train Regression Error: 3.597, Val Regression Loss: 0.029, Val Regression Error: 3.748
#
# Epoch 142,   Train Loss: 0.291,            Train Accuracy: 0.836,            Val Loss: 0.720, Val Accuracy: 0.688,
# Train Regression Loss: 0.028, Train Regression Error: 3.597, Val Regression Loss: 0.029, Val Regression Error: 3.762
#
# Epoch 143,   Train Loss: 0.286,            Train Accuracy: 0.845,            Val Loss: 0.712, Val Accuracy: 0.686,
# Train Regression Loss: 0.028, Train Regression Error: 3.594, Val Regression Loss: 0.029, Val Regression Error: 3.775
#
# Epoch 144,   Train Loss: 0.282,            Train Accuracy: 0.848,            Val Loss: 0.676, Val Accuracy: 0.696,
# Train Regression Loss: 0.028, Train Regression Error: 3.595, Val Regression Loss: 0.029, Val Regression Error: 3.761
#
# Epoch 145,   Train Loss: 0.284,            Train Accuracy: 0.845,            Val Loss: 0.742, Val Accuracy: 0.677,
# Train Regression Loss: 0.028, Train Regression Error: 3.591, Val Regression Loss: 0.029, Val Regression Error: 3.781
#
# Epoch 146,   Train Loss: 0.272,            Train Accuracy: 0.854,            Val Loss: 0.738, Val Accuracy: 0.691,
# Train Regression Loss: 0.028, Train Regression Error: 3.587, Val Regression Loss: 0.029, Val Regression Error: 3.770
#
# Epoch 147,   Train Loss: 0.272,            Train Accuracy: 0.859,            Val Loss: 0.727, Val Accuracy: 0.695,
# Train Regression Loss: 0.028, Train Regression Error: 3.585, Val Regression Loss: 0.029, Val Regression Error: 3.750
#
# Epoch 148,   Train Loss: 0.271,            Train Accuracy: 0.855,            Val Loss: 0.729, Val Accuracy: 0.692,
# Train Regression Loss: 0.028, Train Regression Error: 3.586, Val Regression Loss: 0.029, Val Regression Error: 3.768
#
# Epoch 149,   Train Loss: 0.272,            Train Accuracy: 0.858,            Val Loss: 0.766, Val Accuracy: 0.681,
# Train Regression Loss: 0.028, Train Regression Error: 3.586, Val Regression Loss: 0.029, Val Regression Error: 3.803
#
# Epoch 150,   Train Loss: 0.272,            Train Accuracy: 0.853,            Val Loss: 0.723, Val Accuracy: 0.687,
# Train Regression Loss: 0.028, Train Regression Error: 3.579, Val Regression Loss: 0.029, Val Regression Error: 3.770
#
# Epoch 151,   Train Loss: 0.258,            Train Accuracy: 0.864,            Val Loss: 0.722, Val Accuracy: 0.679,
# Train Regression Loss: 0.028, Train Regression Error: 3.578, Val Regression Loss: 0.029, Val Regression Error: 3.794
#
# Epoch 152,   Train Loss: 0.273,            Train Accuracy: 0.849,            Val Loss: 0.732, Val Accuracy: 0.698,
# Train Regression Loss: 0.028, Train Regression Error: 3.576, Val Regression Loss: 0.029, Val Regression Error: 3.778
#
# Epoch 153,   Train Loss: 0.275,            Train Accuracy: 0.849,            Val Loss: 0.763, Val Accuracy: 0.672,
# Train Regression Loss: 0.028, Train Regression Error: 3.574, Val Regression Loss: 0.029, Val Regression Error: 3.777
#
# Epoch 154,   Train Loss: 0.283,            Train Accuracy: 0.842,            Val Loss: 0.779, Val Accuracy: 0.675,
# Train Regression Loss: 0.028, Train Regression Error: 3.572, Val Regression Loss: 0.029, Val Regression Error: 3.791
#
# Epoch 155,   Train Loss: 0.276,            Train Accuracy: 0.848,            Val Loss: 0.753, Val Accuracy: 0.674,
# Train Regression Loss: 0.028, Train Regression Error: 3.570, Val Regression Loss: 0.029, Val Regression Error: 3.779
#
# Epoch 156,   Train Loss: 0.259,            Train Accuracy: 0.862,            Val Loss: 0.792, Val Accuracy: 0.675,
# Train Regression Loss: 0.028, Train Regression Error: 3.571, Val Regression Loss: 0.029, Val Regression Error: 3.788
#
# Epoch 157,   Train Loss: 0.269,            Train Accuracy: 0.852,            Val Loss: 0.798, Val Accuracy: 0.696,
# Train Regression Loss: 0.028, Train Regression Error: 3.566, Val Regression Loss: 0.029, Val Regression Error: 3.724
#
# Epoch 158,   Train Loss: 0.264,            Train Accuracy: 0.857,            Val Loss: 0.768, Val Accuracy: 0.675,
# Train Regression Loss: 0.028, Train Regression Error: 3.564, Val Regression Loss: 0.029, Val Regression Error: 3.735
#
# Epoch 159,   Train Loss: 0.266,            Train Accuracy: 0.863,            Val Loss: 0.825, Val Accuracy: 0.697,
# Train Regression Loss: 0.027, Train Regression Error: 3.537, Val Regression Loss: 0.030, Val Regression Error: 3.830
#
# Epoch 173,   Train Loss: 0.245,            Train Accuracy: 0.869,            Val Loss: 0.799, Val Accuracy: 0.659,
# Train Regression Loss: 0.027, Train Regression Error: 3.535, Val Regression Loss: 0.029, Val Regression Error: 3.771
#
# Epoch 174,   Train Loss: 0.240,            Train Accuracy: 0.873,            Val Loss: 0.820, Val Accuracy: 0.669,
# Train Regression Loss: 0.027, Train Regression Error: 3.536, Val Regression Loss: 0.029, Val Regression Error: 3.776
#
# Epoch 175,   Train Loss: 0.245,            Train Accuracy: 0.863,            Val Loss: 0.861, Val Accuracy: 0.663,
# Train Regression Loss: 0.027, Train Regression Error: 3.531, Val Regression Loss: 0.030, Val Regression Error: 3.796
#
# Epoch 176,   Train Loss: 0.252,            Train Accuracy: 0.861,            Val Loss: 0.843, Val Accuracy: 0.692,
# Train Regression Loss: 0.027, Train Regression Error: 3.530, Val Regression Loss: 0.030, Val Regression Error: 3.799
#
# Epoch 177,   Train Loss: 0.253,            Train Accuracy: 0.860,            Val Loss: 0.843, Val Accuracy: 0.690,
# Train Regression Loss: 0.027, Train Regression Error: 3.527, Val Regression Loss: 0.029, Val Regression Error: 3.736
#
# Epoch 178,   Train Loss: 0.246,            Train Accuracy: 0.866,            Val Loss: 0.831, Val Accuracy: 0.672,
# Train Regression Loss: 0.027, Train Regression Error: 3.526, Val Regression Loss: 0.030, Val Regression Error: 3.796
#
# Epoch 179,   Train Loss: 0.238,            Train Accuracy: 0.872,            Val Loss: 0.844, Val Accuracy: 0.687,
# Train Regression Loss: 0.027, Train Regression Error: 3.529, Val Regression Loss: 0.029, Val Regression Error: 3.773
#
# Epoch 180,   Train Loss: 0.239,            Train Accuracy: 0.870,            Val Loss: 0.795, Val Accuracy: 0.675,
# Train Regression Loss: 0.027, Train Regression Error: 3.521, Val Regression Loss: 0.030, Val Regression Error: 3.838
#
# Epoch 181,   Train Loss: 0.238,            Train Accuracy: 0.869,            Val Loss: 0.837, Val Accuracy: 0.682,
# Train Regression Loss: 0.027, Train Regression Error: 3.520, Val Regression Loss: 0.030, Val Regression Error: 3.826
#
# Epoch 182,   Train Loss: 0.234,            Train Accuracy: 0.875,            Val Loss: 0.871, Val Accuracy: 0.682,
# Train Regression Loss: 0.027, Train Regression Error: 3.516, Val Regression Loss: 0.030, Val Regression Error: 3.798
#
# Epoch 183,   Train Loss: 0.234,            Train Accuracy: 0.876,            Val Loss: 0.877, Val Accuracy: 0.711,
# Train Regression Loss: 0.027, Train Regression Error: 3.516, Val Regression Loss: 0.029, Val Regression Error: 3.756
#
# Epoch 184,   Train Loss: 0.237,            Train Accuracy: 0.872,            Val Loss: 0.857, Val Accuracy: 0.701,
# Train Regression Loss: 0.027, Train Regression Error: 3.513, Val Regression Loss: 0.030, Val Regression Error: 3.778
#
# Epoch 185,   Train Loss: 0.234,            Train Accuracy: 0.873,            Val Loss: 0.806, Val Accuracy: 0.684,
# Train Regression Loss: 0.027, Train Regression Error: 3.515, Val Regression Loss: 0.030, Val Regression Error: 3.788
#
# Epoch 186,   Train Loss: 0.232,            Train Accuracy: 0.870,            Val Loss: 0.865, Val Accuracy: 0.702,
# Train Regression Loss: 0.027, Train Regression Error: 3.514, Val Regression Loss: 0.030, Val Regression Error: 3.823
#
# Epoch 187,   Train Loss: 0.223,            Train Accuracy: 0.883,            Val Loss: 0.881, Val Accuracy: 0.676,
# Train Regression Loss: 0.027, Train Regression Error: 3.507, Val Regression Loss: 0.030, Val Regression Error: 3.778
#
# Epoch 188,   Train Loss: 0.228,            Train Accuracy: 0.875,            Val Loss: 0.804, Val Accuracy: 0.686,
# Train Regression Loss: 0.027, Train Regression Error: 3.505, Val Regression Loss: 0.030, Val Regression Error: 3.810
#
# Epoch 189,   Train Loss: 0.229,            Train Accuracy: 0.875,            Val Loss: 0.869, Val Accuracy: 0.688,
# Train Regression Loss: 0.027, Train Regression Error: 3.502, Val Regression Loss: 0.030, Val Regression Error: 3.803
#
# Epoch 190,   Train Loss: 0.226,            Train Accuracy: 0.879,            Val Loss: 0.885, Val Accuracy: 0.663,
# Train Regression Loss: 0.027, Train Regression Error: 3.503, Val Regression Loss: 0.030, Val Regression Error: 3.847
#
# Epoch 191,   Train Loss: 0.234,            Train Accuracy: 0.869,            Val Loss: 0.864, Val Accuracy: 0.684,
# Train Regression Loss: 0.027, Train Regression Error: 3.503, Val Regression Loss: 0.030, Val Regression Error: 3.816
#
# Epoch 192,   Train Loss: 0.235,            Train Accuracy: 0.868,            Val Loss: 0.839, Val Accuracy: 0.694,
# Train Regression Loss: 0.027, Train Regression Error: 3.500, Val Regression Loss: 0.030, Val Regression Error: 3.808
#
# Epoch 193,   Train Loss: 0.231,            Train Accuracy: 0.874,            Val Loss: 0.865, Val Accuracy: 0.664,
# Train Regression Loss: 0.027, Train Regression Error: 3.493, Val Regression Loss: 0.030, Val Regression Error: 3.773
#
# Epoch 194,   Train Loss: 0.225,            Train Accuracy: 0.877,            Val Loss: 0.870, Val Accuracy: 0.687,
# Train Regression Loss: 0.027, Train Regression Error: 3.492, Val Regression Loss: 0.030, Val Regression Error: 3.795
#
# Epoch 195,   Train Loss: 0.229,            Train Accuracy: 0.872,            Val Loss: 0.859, Val Accuracy: 0.674,
# Train Regression Loss: 0.027, Train Regression Error: 3.491, Val Regression Loss: 0.030, Val Regression Error: 3.780
#
# Epoch 196,   Train Loss: 0.226,            Train Accuracy: 0.876,            Val Loss: 0.887, Val Accuracy: 0.687,
# Train Regression Loss: 0.027, Train Regression Error: 3.492, Val Regression Loss: 0.030, Val Regression Error: 3.836
#
# Epoch 197,   Train Loss: 0.226,            Train Accuracy: 0.876,            Val Loss: 0.948, Val Accuracy: 0.674,
# Train Regression Loss: 0.027, Train Regression Error: 3.489, Val Regression Loss: 0.031, Val Regression Error: 3.884
#
# Epoch 198,   Train Loss: 0.238,            Train Accuracy: 0.866,            Val Loss: 0.891, Val Accuracy: 0.677,
# Train Regression Loss: 0.027, Train Regression Error: 3.491, Val Regression Loss: 0.030, Val Regression Error: 3.819
#
# Epoch 199,   Train Loss: 0.220,            Train Accuracy: 0.879,            Val Loss: 0.891, Val Accuracy: 0.693,
# Train Regression Loss: 0.027, Train Regression Error: 3.489, Val Regression Loss: 0.029, Val Regression Error: 3.768
#
# best Epoch:  167 , best total train loss:  0.027546018569005862 , best total val loss:  0.02952594485353021
# graph classification train acc:  0.8793981481481482 graph classification val acc:  0.6928733031674208
# regression train error:  3.4888255437215165 regression test error:  3.768251140102756

# %% [markdown]
# best Epoch:  173 , best total train loss:  0.027313787231428757 , best total val loss:  0.0294601630200358
# graph classification train acc:  0.8805555555555555 graph classification val acc:  0.7162047511312217
# regression train error:  3.4533276381316007 regression test error:  3.7947435231917686
#
# Epoch 49,   Train Loss: 0.416,            Train Accuracy: 0.835,            Val Loss: 0.696, Val Accuracy: 0.680,
# Train Regression Loss: 0.030, Train Regression Error: 3.824, Val Regression Loss: 0.029, Val Regression Error: 3.818
#
# Epoch 89,   Train Loss: 0.270,            Train Accuracy: 0.914,            Val Loss: 0.853, Val Accuracy: 0.669,
# Train Regression Loss: 0.029, Train Regression Error: 3.717, Val Regression Loss: 0.029, Val Regression Error: 3.754

# %%
model.train()
loss_fn = torch.nn.BCEWithLogitsLoss()
loss_mse = torch.nn.MSELoss()

for epoch in range(args.epochs):
    best_train_loss, best_val_loss = float("inf"), float("inf")
    losses = []
    correct = 0

    for data in train_loader:
        data.to(args.device)
        data_input = data.x, data.edge_index, data.batch, data.edge_attr

        labels = data.y
        gt = []
        for label in labels:
            if label == 0:
                gt.append([1,0])
            else:
                gt.append([0,1])
        gt = torch.tensor(gt, dtype=torch.float32).to(args.device)
        scores = model(data_input)[0]
        loss = loss_fn(scores, gt)
        pred = scores.argmax(dim=1)
        correct += int((pred == labels).sum()) / labels.size(0)
        losses.append(loss.item())
 
        # backprop
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    epoch_loss_train = sum(losses) / len(losses)
    epoch_acc_train = correct / len(train_loader)

    # validation
    losses = []
    correct = 0

    for data in val_loader:
        data.to(args.device)

        data_input = data.x, data.edge_index, data.batch, data.edge_attr

        labels = data.y

        gt = []
        for label in labels:
            if label == 0:
                gt.append([1,0])
            else:
                gt.append([0,1])
        gt = torch.tensor(gt, dtype=torch.float32).to(args.device)


        # get class scores from model
        scores = model(data_input)[0]

        loss = loss_fn(scores, gt)

        # Keep track of loss and accuracy
        pred = scores.argmax(dim=1)
        correct += int((pred == labels).sum()) / labels.size(0)
        losses.append(loss.item())

    # gather the results for the epoch
    epoch_loss_val = sum(losses) / len(losses)
    epoch_acc_val = correct / len(val_loader)

    log = "Epoch {},   Train Loss: {:.3f},            Train Accuracy: {:.3f},            Val Loss: {:.3f}, Val Accuracy: {:.3f}"
    print(log.format(epoch, 
                     epoch_loss_train, epoch_acc_train, epoch_loss_val, epoch_acc_val))

    is_best_loss = False
    if epoch_loss_val < best_val_loss:
        best_epoch, best_train_graph_loss, best_val_loss, is_best_loss = epoch, epoch_loss_train, epoch_loss_val, True

model.save_checkpoint(os.path.join("logs", args.save), optimizer, epoch, best_train_graph_loss, best_val_loss, is_best_loss)
print('best Epoch: ', best_epoch, ', best total train loss: ', best_train_graph_loss, ', best total val loss: ', best_val_loss)

# %%
best_epoch, best_train_loss, best_val_loss = model.load_checkpoint(os.path.join("logs", args.save), optimizer)
model.eval()

losses = []
edge_losses = []
reg_losses = []
correct = 0
edge_correct = 0
frame_error = 0

for data in test_loader:
    data.to(args.device)

    data_input = data.x, data.edge_index, data.batch, data.edge_attr

    labels = data.y

    gt = []
    for label in labels:
        if label == 0:
            gt.append([1,0])
        else:
            gt.append([0,1])
    gt = torch.tensor(gt, dtype=torch.float32).to(args.device)


    # get class scores from model
    scores = model(data_input)[0]

    loss = loss_fn(scores, gt)

    # Keep track of loss and accuracy
    pred = scores.argmax(dim=1)
    correct += int((pred == labels).sum()) / labels.size(0)
    losses.append(loss.item())


    batch_node_label = []
    for data_point in data.batch:
        if data.y[data_point] == 0:
            batch_node_label.append(False)
        else:
            batch_node_label.append(True)
    batch_node_label = torch.tensor(batch_node_label, dtype=torch.bool).to(args.device)
    batch_edge_label = batch_node_label[data.edge_index[0]]
    edge_score = model(data_input)[1][batch_edge_label]
    gt_edge = []
    batch_edge_index = data.obj_ids[data.edge_index[0]][batch_edge_label]
    for i in range(edge_score.size(0)):
        if batch_edge_index[i] in data.crash_ids:
            gt_edge.append([0,1])
        else:
            gt_edge.append([1,0])
    gt_edge = torch.tensor(gt_edge, dtype=torch.float32).to(args.device)
    loss_edge = loss_fn(edge_score, gt_edge)
    edge_losses.append(loss_edge.item())
    pred_edge = edge_score.argmax(dim=1)
    labels_edge = gt_edge.argmax(dim=1)
    edge_correct += int((pred_edge == labels_edge).sum()) / labels_edge.size(0)


    regression_score = model(data_input)[2][data.y == 1]
    regression_gt = data.frame_to_crash[data.y == 1]
    loss_reg = torch.sqrt(loss_mse(torch.flatten(regression_score, start_dim=0), regression_gt))/t_prediction
    frame_error += abs(torch.sub(torch.flatten(regression_score, start_dim=0), regression_gt)).sum().item() / regression_gt.size(0)
    reg_losses.append(loss_reg.item())

# gather the results for the epoch
loss_test = sum(losses) / len(losses)
correct_test = correct / len(test_loader)
epoch_edge_loss_test = sum(edge_losses) / len(edge_losses)
epoch_edge_acc_test = edge_correct / len(test_loader)
epoch_reg_loss_test = sum(reg_losses) / len(reg_losses)
epoch_reg_error_test = frame_error / len(test_loader)

print("Test Loss at epoch {}: {:.3f}, Test Accuracy: {:.3f}, \nTest Edge Loss: {:.3f}, Test Edge Accuracy: {:.3f} \nTest Regression Loss: {:.3f}, Test Regression Error: {:.3f}".format(best_epoch, loss_test, correct_test, epoch_edge_loss_test, epoch_edge_acc_test, epoch_reg_loss_test, epoch_reg_error_test))
# Out:
# Test Loss at epoch 99: 2.376, Test Accuracy: 0.720,
# Test Edge Loss: 0.604, Test Edge Accuracy: 0.821
# Test Regression Loss: 0.301, Test Regression Error: 7.256
